# %% [markdown]
# <a href="https://colab.research.google.com/github/emilianoCabrera/Retail_Store_CoderHouse/blob/main/Dataset_Retail_Store_Cabrera_Emiliano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/datasets/rohitsahoo/sales-forecasting
#
# Retail dataset of a global superstore for 4 years. Since 2015 to 2018.

# %%
! git clone https://github.com/emilianoCabrera/Retail_Store_CoderHouse.git
# Out:
# Cloning into 'Retail_Store_CoderHouse'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), 849.62 KiB | 2.31 MiB/s, done.

# %%
import pandas as pd
df_Store=pd.read_csv('/content/Retail_Store_CoderHouse/Retail_Store.csv')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
mpl.style.use('bmh')

# %%
fig, ax = plt.subplots()

x = ["A","B","C"]
y = ["13","24","33"]
plt.bar (x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
df_Index = df_Store['Order Date']
print(df_Store)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df_sum=df_Store.sum(axis='rows')
print(df_sum)
# Out:
# Row ID                                                    48024900
# Order ID         CA-2017-152156CA-2017-152156CA-2017-138688US-2...
# Order Date       08/11/201708/11/201712/06/201711/10/201611/10/...
# Ship Date        11/11/201711/11/201716/06/201718/10/201618/10/...
# Ship Mode        Second ClassSecond ClassSecond ClassStandard C...
# Customer ID      CG-12520CG-12520DV-13045SO-20335SO-20335BH-117...
# Customer Name    Claire GuteClaire GuteDarrin Van HuffSean O'Do...
# Segment          ConsumerConsumerCorporateConsumerConsumerConsu...
# Country          United StatesUnited StatesUnited StatesUnited ...
# City             HendersonHendersonLos AngelesFort LauderdaleFo...
# State            KentuckyKentuckyCaliforniaFloridaFloridaCalifo...
# Postal Code                                            541070553.0
# Region           SouthSouthWestSouthSouthWestWestWestWestWestWe...
# Product ID       FUR-BO-10001798FUR-CH-10000454OFF-LA-10000240F...
# ...

# %%
df_x=df_Index.index
print(df_x)
# Out:
# RangeIndex(start=0, stop=9800, step=1)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas as pd

# %%
df_Store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df_Store.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df_Store[["Sales", "City", "Product Name","Region","Order Date"]]

#df_Store.sort("Sales")
# Out:
#          Sales             City  \
# 0     261.9600        Henderson
# 1     731.9400        Henderson
# 2      14.6200      Los Angeles
# 3     957.5775  Fort Lauderdale
# 4      22.3680  Fort Lauderdale
# ...        ...              ...
# 9795    3.7980          Chicago
# 9796   10.3680           Toledo
# 9797  235.1880           Toledo
# 9798   26.3760           Toledo
# 9799   10.3840           Toledo
#
#                                            Product Name   Region  Order Date
# 0                     Bush Somerset Collection Bookcase    South  08/11/2017
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...    South  08/11/2017
# 2     Self-Adhesive Address Labels for Typewriters b...     West  12/06/2017
# 3         Bretford CR4500 Series Slim Rectangular Table    South  11/10/2016
# 4                        Eldon Fold 'N Roll Cart System    South  11/10/2016
# ...                                                 ...      ...         ...
# ...

# %%
top10 = df_Store [ df_Store["Sales"]>8200.00 ]

# %%
# Se intenta realizar el Top10 como me dijiste pero el gráfico por algún motivo no lo respeta, aunque reconoce los montos.
#  Se puede ver en la diferenciación de  los 2 graficos de torta siguientes.

serie = top10.City.value_counts("Sales")
serie.plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='City'>

# %%
serie = top10.Sales.value_counts("City")
serie.plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
# No separa la torta como corresponde.

# %%
#Grafico de Scatter - Establecer Periodos de mayor venta.

df_Store.plot.scatter(y="Sales", x="Order Date")
# Out:
# <Axes: xlabel='Order Date', ylabel='Sales'>

# %%
# Lo que se intentó realizar fue establecer en que fechas incrementa exponencialmente las ventas. Pero NO se observan claramente las fechas.
# Se estima que hubo un incremento sustancias en el año 2017.

# %%
# Grafico de Barras con Matplotlib - Regiones segun cantidad de ventas


sns.set_theme()
sns.countplot(x="Region", data=df_Store)
plt.show()

# %%
# Se intenta saber qué Región de USA es la que mayor volumen de ventas posee. Por lo que se observa la Zona Oeste y la zona Este son las que mayor cantidad
# de ventas han realizado.

# %%
#Histograma en Matplotlib - Ciudad con mayor volumen de ventas ordenadas por fechas. 

df_Store[["Sales","Order Date"]]
plt.hist(df_Store['State'], bins=20, alpha=0.50)
plt.show()

# %%
# Se buscó establecer que ciudad fue la de mayor cantidad de ventas realizadas durante el período completo
# La cantidad de valores no hace visible a que ciudad corresponde.

# %%
# PIE CHART en Matplotlib - Ciudades con volumenes de ventas.

serie = df_Store.City.value_counts()
serie.plot.pie()
# Out:
# <Axes: ylabel='City'>

# %%
# Con este grafico de Torta, se observa que el 50 % de las ventas realizadas se encuentran concentradas en 15 ciudades,
# en la otra mitad se encuentran el resto de las 516 ciudades.

# %%
a = "City"

print (a)
# Out:
# City

# %%
# HISTOGRAMA en Seaborn - Calculo de Región con mayor número de ventas.

import seaborn as sns
sns.histplot(data=df_Store, x="Region", hue="State", multiple="stack")
# Out:
# <Axes: xlabel='Region', ylabel='Count'>

# %%
# Como se puede observar(Aunque el Hue, esté tapando el grafico, y no puedo moverlo),
# la zona Oeste de USA es la que acumula un mayor volumen de ventas. Esto es dado por el Estado de California.

# %%
# HISTOGRAMA en Seaborn - Calculo de Región con mayor número de ventas 

sns.histplot(data=top10, x="Region", y="Sales", hue="City", multiple="stack")
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
xo = df_Store('State')
yo = df_Store('Sales')

plt.plot
plt.bar(xo,yo, color='y', linestyle="--")



plt.xlabel ("Estados de USA")
plt.ylabel ("Ventas totales Acumudadas")
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-a8ec747b4c80> in <cell line: 1>()
# ----> 1 xo = df_Store('State')
#       2 yo = df_Store('Sales')
#       3
#       4 plt.plot
#       5 plt.bar(xo,yo, color='y', linestyle="--")
#
# TypeError: 'DataFrame' object is not callable

# %%
sns.histplot?

# %%
# Grafico de Dispersión por fecha - 

sns.set_theme(style="dark")
g = sns.relplot(data=top10, x="Order Date", y="Sales", hue="Region")

# %%
# Se intentó con el Top10  conocer como era la dispersión de los top10 con mayores ventas.
# Continuo teniendo inconvenientes para que se observen as fechas.

# %%
df_Store, ax= plt.subplots(figsize (7,7),nrows=2,ncols=2)
#df_Store.suptitle('Graficos Comparables')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-d2b862df5f6e> in <cell line: 1>()
# ----> 1 df_Store, ax= plt.subplots(figsize (7,7),nrows=2,ncols=2)
#       2 #df_Store.suptitle('Graficos Comparables')
#
# NameError: name 'figsize' is not defined

# %%
g = sns.facegrid(df_Store,col="Date Order",row="Sales")
g.map(sns.scatterplot,"Region")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-b882bf86fae1> in <cell line: 1>()
# ----> 1 g = sns.facegrid(df_Store,col="Date Order",row="Sales")
#       2 g.map(sns.scatterplot,"Region")
#
# AttributeError: module 'seaborn' has no attribute 'facegrid'
